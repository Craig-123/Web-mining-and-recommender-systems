# %% [markdown]
# # WEB USAGE MINING: ANALYTICS

# %% [markdown]
# ### Regular expressions

# %%
from datetime import datetime
import pytz
#%h %l %u %t \"%r\" %>s %b \"%{Referer}i\" \"%{User-agent}i\"
def parse_str(x):
    """
    Returns the string delimited by two characters.
    Example:
    `>>> parse_str('[my string]')`
    `'my string'`
    """
    if x is None:
        return '-'
    return x[1:-1]

# %% [markdown]
# ### parse_int

# %%
def parse_int(x):
    """Returns parsed string if no error occured during parse
    else returns 0"""
    if x is None:
        return 0
    try:
        y = int(x)
        return y
    except ValueError:
        return 0

# %%
def parse_datetime(x):
    '''
    Parses datetime with timezone formatted as:
    `[day/month/year:hour:minute:second zone]`
    Example:
    `>>> parse_datetime('13/Nov/2015:11:45:42 +0000')`
    `datetime.datetime(2015, 11, 3, 11, 45, 4, tzinfo=<UTC>)`
    Due to problems parsing the timezone (`%z`) with
    `datetime.strptime`, the
    timezone will be obtained using the `pytz` library.
    '''
    try:
        dt = datetime.strptime(x[1:-7], '%d/%b/%Y:%H:%M:%S')
        dt_tz = int(x[-6:-3])*60+int(x[-3:-1])
        return dt.replace(tzinfo=pytz.FixedOffset(dt_tz))
    except ValueError:
        return '-'

# %%
import re
import pandas as pd

# %%
conv = {'time': parse_datetime,
'request': parse_str,
'status': parse_int,
'size': parse_int,
'referer': parse_str,
'user_agent': parse_str}

# %%
data = pd.read_csv('apache_logs.txt', header=None, error_bad_lines=False, sep=r'\s(?=(?:[^"]*"[^"]*")*[^"]*$)(?![^\[]*\])',
engine='python', na_values='-', usecols=[0, 3, 4, 5, 6, 7, 8],
#names=['ip', 'time', 'request', 'status', 'size','referer', 'user_agent'],
names=['Client_IP_address',
'Time_of_activity','Requested_Page', 'Status_Code', 'Size_of_Page',
'Referer_page','Client_Device'], converters=conv)
# Out:
# C:\Users\Tanaka\AppData\Local\Temp\ipykernel_18452\3519115392.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   data = pd.read_csv('apache_logs.txt', header=None, error_bad_lines=False, sep=r'\s(?=(?:[^"]*"[^"]*")*[^"]*$)(?![^\[]*\])',

# %%
data.head()
# Out:
#   Client_IP_address              Time_of_activity  \
# 0      83.149.9.216  [17/May/2015:10:05:03 +0000]
# 1      83.149.9.216  [17/May/2015:10:05:43 +0000]
# 2      83.149.9.216  [17/May/2015:10:05:47 +0000]
# 3      83.149.9.216  [17/May/2015:10:05:12 +0000]
# 4      83.149.9.216  [17/May/2015:10:05:07 +0000]
#
#                                       Requested_Page Status_Code  \
# 0  "GET /presentations/logstash-monitorama-2013/i...         200
# 1  "GET /presentations/logstash-monitorama-2013/i...         200
# 2  "GET /presentations/logstash-monitorama-2013/p...         200
# 3  "GET /presentations/logstash-monitorama-2013/p...         200
# 4  "GET /presentations/logstash-monitorama-2013/p...         200
#
#    Size_of_Page                                       Referer_page  \
# 0      203023.0  "http://semicomplete.com/presentations/logstas...
# 1      171717.0  "http://semicomplete.com/presentations/logstas...
# 2       26185.0  "http://semicomplete.com/presentations/logstas...
# 3        7697.0  "http://semicomplete.com/presentations/logstas...
# 4        2892.0  "http://semicomplete.com/presentations/logstas...
#
#                                        Client_Device
# 0  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_1...
# 1  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_1...
# 2  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_1...
# 3  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_1...
# 4  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_1...

# %%
IP=set(data['Client_IP_address'])
len(IP)
# Out:
# 1754

# %%
devices=set(data['Client_Device'])
len(devices)
# Out:
# 559

# %%
D={}
for i,row in data.iterrows():
    if(tuple((row['Client_IP_address'],row['Client_Device'])) in D):
        D[tuple((row['Client_IP_address'],row['Client_Device']))]+=1
    else:
        D[tuple((row['Client_IP_address'],row['Client_Device']))]=1

# %% [markdown]
# 10 people who visited frequently

# %%
freq = sorted(D, key = D.get, reverse = True)
top_10 = freq[:10]
for i,j in enumerate(top_10, start=1):
    print(i,"",j)
# Out:
# 1  ('46.105.14.53', '"UniversalFeedParser/4.2-pre-314-svn +http://feedparser.org/"')
# 2  ('130.237.218.86', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/33.0.1750.91 Safari/537.36"')
# 3  ('75.97.9.59', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/32.0.1700.107 Safari/537.36"')
# 4  ('66.249.73.135', '"Mozilla/5.0 (iPhone; CPU iPhone OS 6_0 like Mac OS X) AppleWebKit/536.26 (KHTML, like Gecko) Version/6.0 Mobile/10A5376e Safari/8536.25 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)"')
# 5  ('66.249.73.135', '"Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)"')
# 6  ('50.16.19.13', '"Tiny Tiny RSS/1.11 (http://tt-rss.org/)"')
# 7  ('68.180.224.225', '"Mozilla/5.0 (compatible; Yahoo! Slurp; http://help.yahoo.com/help/us/ysearch/slurp)"')
# 8  ('208.115.111.72', '"Mozilla/5.0 (compatible; Ezooms/1.0; help@moz.com)"')
# 9  ('198.46.149.143', '"Tiny Tiny RSS/1.11 (http://tt-rss.org/)"')
# 10  ('208.115.113.88', '"Mozilla/5.0 (compatible; Ezooms/1.0; help@moz.com)"')

# %% [markdown]
# Sessions and page views per session

# %%
time=[]
page=[]
al=[]
for i in list(D)[:500]:
    for j,row in data.iterrows():
        if(i==tuple((row['Client_IP_address'],row['Client_Device']))):
            time.append(row['Time_of_activity'])
            page.append(row['Requested_Page'])
            al.append(i)

# %%
df=pd.DataFrame({'Time':time,'Pages':page,'Client':al})
df.head()
# Out:
#                            Time  \
# 0  [17/May/2015:10:05:03 +0000]
# 1  [17/May/2015:10:05:43 +0000]
# 2  [17/May/2015:10:05:47 +0000]
# 3  [17/May/2015:10:05:12 +0000]
# 4  [17/May/2015:10:05:07 +0000]
#
#                                                Pages  \
# 0  "GET /presentations/logstash-monitorama-2013/i...
# 1  "GET /presentations/logstash-monitorama-2013/i...
# 2  "GET /presentations/logstash-monitorama-2013/p...
# 3  "GET /presentations/logstash-monitorama-2013/p...
# 4  "GET /presentations/logstash-monitorama-2013/p...
#
#                                               Client
# 0  (83.149.9.216, "Mozilla/5.0 (Macintosh; Intel ...
# 1  (83.149.9.216, "Mozilla/5.0 (Macintosh; Intel ...
# 2  (83.149.9.216, "Mozilla/5.0 (Macintosh; Intel ...
# 3  (83.149.9.216, "Mozilla/5.0 (Macintosh; Intel ...
# 4  (83.149.9.216, "Mozilla/5.0 (Macintosh; Intel ...

# %% [markdown]
# Five most referrer websites

# %%
referers = data['Referer_page'].dropna(how='all')

# %%
from urllib.parse import urlparse

# %%
ref=[]
for i in referers:
    parsed_uri = urlparse(i.replace('"', ''))
    result = '{uri.scheme}://{uri.netloc}/'.format(uri=parsed_uri)
    ref.append(result)
word_counter = {}

# %%
for url in ref:
    if url in word_counter:
        word_counter[url] += 1
    else:
        word_counter[url] = 1

# %%
popular_words = sorted(word_counter, key = word_counter.get, reverse = True)

# %%
top_5 = popular_words[:6]
for i in top_5:
    if(i==':///'''):
        top_5.remove(i)

# %%
for i,j in enumerate(top_5,start=1):
    print(i,"",j)
# Out:
# 1  http://www.semicomplete.com/
# 2  http://semicomplete.com/
# 3  http://www.google.com/
# 4  https://www.google.com/
# 5  http://stackoverflow.com/

# %% [markdown]
# Ten most frequent patterns

# %%
Pages_visited_per_session=list(df['Pages'])
Pages_accessed={}
for i,row in df.iterrows():
    if(row['Client'] in Pages_accessed):
        Pages_accessed[row['Client']].append(row['Pages'])
    else:
        Pages_accessed[row['Client']]=[row['Pages']]

# %%
for i in Pages_accessed:
    print('\n Client {} accessed these pages \n {}\n'.format(i,Pages_accessed[i]))
# Out:
#  Client ('83.149.9.216', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/32.0.1700.77 Safari/537.36"') accessed these pages
#  ['"GET /presentations/logstash-monitorama-2013/images/kibana-search.png HTTP/1.1"', '"GET /presentations/logstash-monitorama-2013/images/kibana-dashboard3.png HTTP/1.1"', '"GET /presentations/logstash-monitorama-2013/plugin/highlight/highlight.js HTTP/1.1"', '"GET /presentations/logstash-monitorama-2013/plugin/zoom-js/zoom.js HTTP/1.1"', '"GET /presentations/logstash-monitorama-2013/plugin/notes/notes.js HTTP/1.1"', '"GET /presentations/logstash-monitorama-2013/images/sad-medic.png HTTP/1.1"', '"GET /presentations/logstash-monitorama-2013/css/fonts/Roboto-Bold.ttf HTTP/1.1"', '"GET /presentations/logstash-monitorama-2013/css/fonts/Roboto-Regular.ttf HTTP/1.1"', '"GET /presentations/logstash-monitorama-2013/images/frontend-response-codes.png HTTP/1.1"', '"GET /presentations/logstash-monitorama-2013/images/kibana-dashboard.png HTTP/1.1"', '"GET /presentations/logstash-monitorama-2013/images/Dreamhost_logo.svg HTTP/1.1"', '"GET /presentations/logstash-monitorama-2013/images/kibana-dashboard2.png HTTP/1.1"', '"GET /presentations/logstash-monitorama-2013/images/apache-icon.gif HTTP/1.1"', '"GET /presentations/logstash-monitorama-2013/images/nagios-sms5.png HTTP/1.1"', '"GET /presentations/logstash-monitorama-2013/images/redis.png HTTP/1.1"', '"GET /presentations/logstash-monitorama-2013/images/elasticsearch.png HTTP/1.1"', '"GET /presentations/logstash-monitorama-2013/images/logstashbook.png HTTP/1.1"', '"GET /presentations/logstash-monitorama-2013/images/github-contributions.png HTTP/1.1"', '"GET /presentations/logstash-monitorama-2013/css/print/paper.css HTTP/1.1"', '"GET /presentations/logstash-monitorama-2013/images/1983_delorean_dmc-12-pic-38289.jpeg HTTP/1.1"', '"GET /presentations/logstash-monitorama-2013/images/simple-inputs-filters-outputs.jpg HTTP/1.1"', '"GET /presentations/logstash-monitorama-2013/images/tiered-outputs-to-inputs.jpg HTTP/1.1"', '"GET /favicon.ico HTTP/1.1"']
#
#
#  Client ('24.236.252.67', '"Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:26.0) Gecko/20100101 Firefox/26.0"') accessed these pages
#  ['"GET /favicon.ico HTTP/1.1"']
#
#
#  Client ('93.114.45.13', '"Mozilla/5.0 (X11; Linux x86_64; rv:25.0) Gecko/20100101 Firefox/25.0"') accessed these pages
#  ['"GET /articles/dynamic-dns-with-dhcp/ HTTP/1.1"', '"GET /reset.css HTTP/1.1"', '"GET /style2.css HTTP/1.1"', '"GET /favicon.ico HTTP/1.1"', '"GET /images/jordan-80.png HTTP/1.1"', '"GET /images/web/2009/banner.png HTTP/1.1"']
#
#
#  Client ('66.249.73.135', '"Mozilla/5.0 (iPhone; CPU iPhone OS 6_0 like Mac OS X) AppleWebKit/536.26 (KHTML, like Gecko) Version/6.0 Mobile/10A5376e Safari/8536.25 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)"') accessed these pages
#  ['"GET /blog/tags/ipv6 HTTP/1.1"', '"GET /blog/geekery/eventdb-ideas.html HTTP/1.1"', '"GET /blog/geekery/vmware-cpu-performance.html HTTP/1.1"', '"GET /blog/web/firefox-scrolling-fix.html HTTP/1.1"', '"GET /blog/geekery/rhapsody-on-linux.html HTTP/1.1"', '"GET /blog/geekery/xdotool-2.20110530.html HTTP/1.1"', '"GET /blog/tags/linux HTTP/1.1"', '"GET /blog/geekery/sparsa2006.html HTTP/1.1"', '"GET /blog/tags/C HTTP/1.1"', '"GET /blog/tags/xpathtool HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /blog/geekery/grok-and-eventdb.html HTTP/1.1"', '"GET /blog/geekery/solving-good-or-bad-problems.html HTTP/1.1"', '"GET /blog/tags/Xlib HTTP/1.1"', '"GET /blog/tags/assert HTTP/1.1"', '"GET /blog/tags/barcampsf HTTP/1.1"', '"GET /blog/tags/gtk HTTP/1.1"', '"GET /blog/tags/rants HTTP/1.1"', '"GET /blog/tags/music HTTP/1.1"', '"GET /blog/tags/release HTTP/1.1"', '"GET /blog/tags/shmoocon2007 HTTP/1.1"', '"GET /blog/tags/shmoocon HTTP/1.1"', '"GET /blog/tags/tools HTTP/1.1"', '"GET /blog/tags/windows HTTP/1.1"', '"GET /blog/tags/year%20review HTTP/1.1"', '"GET /files/blogposts/20071009/dxargs.py HTTP/1.1"', '"GET /scripts/gterm.sh HTTP/1.1"', '"GET /scripts/tagcloud.py HTTP/1.1"', '"GET /blog/geekery/118.html HTTP/1.1"', '"GET /blog/geekery/grok-and-advanced-regex HTTP/1.1"', '"GET /blog/geekery/grok-like-grep.html HTTP/1.1"', '"GET /blog/geekery/yahoo-hackday-08.html HTTP/1.1"', '"GET /blog/geekery/year-in-review-2007.html HTTP/1.1"', '"GET /blog/geekery/year-in-review-2011.html HTTP/1.1"', '"GET /blog/site/site-design-2009.html HTTP/1.1"', '"GET /blog/tags/alert HTTP/1.1"', '"GET /blog/tags/log HTTP/1.1"', '"GET /blog/tags/project HTTP/1.1"', '"GET /blog/tags/xdo HTTP/1.1"', '"GET /misc/rcfiles/zshrc HTTP/1.1"', '"GET /scripts/python/wrap/happyfoo.py HTTP/1.1"', '"GET /scripts/python/wrap/main.py HTTP/1.1"', '"GET /scripts/python/wrap/wrap.py HTTP/1.1"', '"GET /blog/geekery/sequencing-and-searching-strings HTTP/1.1"', '"GET /blog/rants/forbes-dot-com-sucks.html HTTP/1.1"', '"GET /blog/tags/logs HTTP/1.1"', '"GET /blog/tags/networking HTTP/1.1"', '"GET /files/xdotool/docs/html/globals.html HTTP/1.1"', '"GET /blog/geekery/tsawm-window-manager-project.html HTTP/1.1"', '"GET /files/xdotool/docs/html/xdo_8h_source.html HTTP/1.1"', '"GET /projects/tastydrive/tastydrive.py HTTP/1.1"', '"GET /blog/geekery/sms-traffic-reports.html HTTP/1.1"', '"GET /blog/tags/databases HTTP/1.1"', '"GET /blog/tags/pipe HTTP/1.1"', '"GET /blog/tags/service%20providers HTTP/1.1"', '"GET /blog/tags/ewmh HTTP/1.1"', '"GET /blog/tags/pam_captcha HTTP/1.1"', '"GET /blog/geekery/python-cgrok-bindings-2.html HTTP/1.1"', '"GET /blog/tags/flex HTTP/1.1"', '"GET /blog/geekery/xdotool-2.20100818.html HTTP/1.1"', '"GET /blog/tags/embedding HTTP/1.1"', '"GET /blog/tags/libpcre HTTP/1.1"', '"GET /blog/tags/fix HTTP/1.1"', '"GET /blog/tags/indexing HTTP/1.1"', '"GET /blog/geekery/ie-javascript-error.html HTTP/1.1"', '"GET /blog/geekery/splitting-large-logs.html HTTP/1.1"', '"GET /blog/geekery/vim-function-to-make-errors-readable.html HTTP/1.1"', '"GET /files/blogposts/20070915/patch-ruby1.8.6-regparse.c HTTP/1.1"', '"GET /files/xdotool/docs/html/structxdo__search.html HTTP/1.1"', '"GET /files/blogposts/20080611/pcapinject.c HTTP/1.1"', '"GET /blog/tags/scapy HTTP/1.1"', '"GET /blog/geekery/pam_captcha_research.html HTTP/1.1"', '"GET /blog/tags/pylons HTTP/1.1"', '"GET /blog/tags/macros HTTP/1.1"', '"GET /blog/tags/extensions HTTP/1.1"', '"GET /blog/productivity/vim-text-objects.html HTTP/1.1"', '"GET /blog/geekery/175.html HTTP/1.1"', '"GET /blog/geekery/low-entropy-captchas.html HTTP/1.1"', '"GET /blog/tags/fancydb HTTP/1.1"', '"GET /blog/geekery/python-dict-merging.html HTTP/1.1"', '"GET /blog/tags/sysadvent2009 HTTP/1.1"', '"GET /blog/tags/flashback2010 HTTP/1.1"', '"GET /blog/tags/laptop HTTP/1.1"', '"GET /blog/site/sitemove4.html HTTP/1.1"', '"GET /blog/geekery/grok-pattern-predicates HTTP/1.1"', '"GET /blog/tags/httpd HTTP/1.1"', '"GET /files/xdotool/docs/html/structcontext.html H ...
#
#
#  Client ('50.16.19.13', '"Tiny Tiny RSS/1.11 (http://tt-rss.org/)"') accessed these pages
#  ['"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"G ...
#
#
#  Client ('66.249.73.185', '"Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)"') accessed these pages
#  ['"GET / HTTP/1.1"', '"GET /reset.css HTTP/1.1"', '"GET /doc/index.html?org/elasticsearch/action/search/SearchResponse.html HTTP/1.1"', '"GET /presentations/logstash-1/ HTTP/1.1"', '"GET /files/firefox-tabsearch/ HTTP/1.1"', '"GET /files/pp/ HTTP/1.1"', '"GET /doc/org/elasticsearch/action/support/master/TransportMasterNodeOperationAction.html HTTP/1.1"', '"GET /files/hello/hello_c HTTP/1.1"', '"GET /files/xdotool/docs/latex/structcharcodemap.tex HTTP/1.1"', '"GET /kibana/ HTTP/1.1"', '"GET /kibana/css/style.css HTTP/1.1"', '"GET /kibana/bootstrap/css/bootstrap.min.css HTTP/1.1"', '"GET /kibana/loader2.php?page=eyJzZWFyY2giOiIiLCJmaWVsZHMiOltdLCJvZmZzZXQiOjAsInRpbWVmcmFtZSI6IjE1IG1pbnV0ZXMiLCJncmFwaG1vZGUiOiJjb3VudCJ9&_=1391904000000 HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /kibana/css/jquery-ui-1.8.16.custom.css HTTP/1.1"', '"GET /kibana/css/jquery.ui.datepicker.css HTTP/1.1"', '"GET /kibana/bootstrap/css/bootstrap-responsive.min.css HTTP/1.1"', '"GET /files/blogposts/20080611/ HTTP/1.1"']
#
#
#  Client ('110.136.166.128', '"Mozilla/5.0 (Windows NT 6.2; WOW64; rv:28.0) Gecko/20100101 Firefox/28.0"') accessed these pages
#  ['"GET /projects/xdotool/ HTTP/1.1"', '"GET /reset.css HTTP/1.1"', '"GET /style2.css HTTP/1.1"', '"GET /favicon.ico HTTP/1.1"', '"GET /images/jordan-80.png HTTP/1.1"', '"GET /images/web/2009/banner.png HTTP/1.1"']
#
#
#  Client ('46.105.14.53', '"UniversalFeedParser/4.2-pre-314-svn +http://feedparser.org/"') accessed these pages
#  ['"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"G ...
#
#
#  Client ('123.125.71.35', '"Mozilla/5.0 (compatible; Baiduspider/2.0; +http://www.baidu.com/search/spider.html)"') accessed these pages
#  ['"GET /blog/tags/release HTTP/1.1"']
#
#
#  Client ('50.150.204.184', '"Mozilla/5.0 (Linux; U; Android 4.0.4; en-us; LG-MS770 Build/IMM76I) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.0 Mobile Safari/534.30"') accessed these pages
#  ['"GET /images/googledotcom.png HTTP/1.1"']
#
#
#  Client ('207.241.237.225', '"Mozilla/5.0 (compatible; archive.org_bot +http://www.archive.org/details/archive.org_bot)"') accessed these pages
#  ['"GET /blog/tags/examples HTTP/1.0"', '"GET /blog/tags/xdotool?page=2 HTTP/1.0"', '"GET /blog/tags/life%20hacks HTTP/1.0"', '"GET /blog/productivity/wakeup-script.html HTTP/1.0"', '"GET /blog/tags/xdo HTTP/1.0"', '"GET /blog/tags/extension HTTP/1.0"', '"GET /blog/geekery/grok-and-eventdb.html HTTP/1.0"', '"GET /blog/tags/weekof HTTP/1.0"', '"GET /blog/geekery/non-compiler-caching.html HTTP/1.0"', '"GET /blog/geekery/year-in-review-2008.html HTTP/1.0"', '"GET /blog/geekery/mysql-prepare-queries-not-cached HTTP/1.0"', '"GET /blog/geekery/grok-pcre-sneak.html HTTP/1.0"', '"GET /blog/articles/week-of-unix-tools/main.html HTTP/1.0"']
#
#
#  Client ('200.49.190.101', '"-"') accessed these pages
#  ['"GET /reset.css HTTP/1.1"', '"GET /style2.css HTTP/1.1"']
#
#
#  Client ('200.49.190.100', '"QS304 Profile/MIDP-2.0 Configuration/CLDC-1.1"') accessed these pages
#  ['"GET /blog/tags/web HTTP/1.1"']
#
#
#  Client ('200.49.190.101', '"QS304 Profile/MIDP-2.0 Configuration/CLDC-1.1"') accessed these pages
#  ['"GET /images/jordan-80.png HTTP/1.1"']
#
#
#  Client ('66.249.73.135', '"Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)"') accessed these pages
#  ['"GET /blog/tags/munin HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET /?flav=atom HTTP/1.1"', '"GET /?flav=rss20 HTTP/1.1"', '"GET /blog/tags/noise HTTP/1.1"', '"GET /blog/tags/scale HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET /?flav=atom HTTP/1.1"', '"GET /blog/tags/c++?page=2 HTTP/1.1"', '"GET /?flav=rss20 HTTP/1.1"', '"GET /projects/xdotool/ HTTP/1.1"', '"GET /blog/tags/kpc650 HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /projects/xdotool%3E HTTP/1.1"', '"GET /?flav=rss20 HTTP/1.1"', '"GET /?flav=atom HTTP/1.1"', '"GET /blog/tags/writing HTTP/1.1"', '"GET /blog/tags/X11 HTTP/1.1"', '"GET /?flav=rss20 HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /?flav=atom HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET /?flav=rss20 HTTP/1.1"', '"GET /blog/geekery/index?page=41 HTTP/1.1"', '"GET /blog/tags/logs HTTP/1.1"', '"GET /blog/index?page=35 HTTP/1.1"', '"GET /?flav=atom HTTP/1.1"', '"GET /~psionic/projects/securitrack/config.xsl HTTP/1.1"', '"GET /projects/securitrack/config.xsl HTTP/1.1"', '"GET /~psionic/projects/securitrack/config.xml HTTP/1.1"', '"GET /projects/securitrack/config.xml HTTP/1.1"', '"GET /blog/tags/site?page=2 HTTP/1.1"', '"GET /blog/tags/nfs HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET /?flav=rss20 HTTP/1.1"', '"GET /?flav=atom HTTP/1.1"', '"GET /articles/dynamic-dns-with-dhcp/ HTTP/1.1"', '"GET /blog/tags/installer%20failure HTTP/1.1"', '"GET /presentations/logstash-hmmm/ HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET /blog/tags/xlib?page=2 HTTP/1.1"', '"GET /?flav=rss20 HTTP/1.1"', '"GET /misc/Title.php.txt HTTP/1.1"', '"GET /?flav=atom HTTP/1.1"', '"GET /blog/articles/week-of-unix-tools/day-4-data-sources.html HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /blog/tags/kyocera HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET /?flav=rss20 HTTP/1.1"', '"GET /?flav=atom HTTP/1.1"', '"GET /blog/tags/speed HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET /files/blogposts/20080611/pcapinject.c HTTP/1.1"', '"GET /?flav=rss20 HTTP/1.1"', '"GET /?flav=atom HTTP/1.1"', '"GET /blog/tags/shell?page=1 HTTP/1.1"', '"GET /blog/tags/shell?page=3 HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET /?flav=rss20 HTTP/1.1"', '"GET /scripts/backup/recover HTTP/1.1"', '"GET /blog/site/183.html HTTP/1.1"', '"GET /?flav=atom HTTP/1.1"', '"GET /blog/tags/year%20review HTTP/1.1"', '"GET /blog/geekery/matplotlib-induces-self-loathing.html?commentlimit=0 HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /blog/misc/cablebox-fix.html HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET /?flav=rss20 HTTP/1.1"', '"GET /projects/keynav HTTP/1.1"', '"GET /projects/keynav/ HTTP/1.1"', '"GET /?flav=atom HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /blog/geekery/impulse-driven-computing.html HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET /articles/openldap-with-saslauthd/ HTTP/1.1"', '"GET /blog/geekery/jquery-i HTTP/1.1"', '"GET /projects/xd HTTP/1.1"', '"GET /?flav=rss20 HTTP/1.1"', '"GET /blog/geekery/jquery-interface-%20 HTTP/1.1"', '"GET /style2.css HTTP/1.1"', '"GET /?flav=atom HTTP/1.1"', '"GET /projects/xdotool/xdotool.xhtml HTTP/1.1"', '"GET /blog/site/165.html HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET /misc/Title.php.txt HTTP/1.1"', '"GET /misc/errors.m4 HTTP/1.1"', '"GET /?flav=atom HTTP/1.1"', '"GET /?flav=rss20 HTTP/1.1"', '"GET /presentations/logstash-monitorama-2013.pdf HTTP/1.1"', '"GET /blog/site/166.html HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET /blog/geekery/index?page=24 HTTP/1.1"', '"GET /blog/tags/thrift HTTP/1.1"', '"GET /?flav=atom HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /?flav=rss20 HTTP/1.1"', '"GET /scripts/fastest_site.py HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET  ...
#
#
#  Client ('67.214.178.190', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10.7; rv:21.0) Gecko/20100101 Firefox/21.0"') accessed these pages
#  ['"GET / HTTP/1.0"', '"GET /blog/geekery/installing-windows-8-consumer-preview.html HTTP/1.0"']
#
#
#  Client ('207.241.237.220', '"Mozilla/5.0 (compatible; archive.org_bot +http://www.archive.org/details/archive.org_bot)"') accessed these pages
#  ['"GET /blog/tags/projects HTTP/1.0"', '"GET /blog/tags/C?page=2 HTTP/1.0"', '"GET /blog/tags/webdriver HTTP/1.0"', '"GET /blog/geekery/eventmachine-tail.html HTTP/1.0"', '"GET /blog/geekery/shebang-fix.html HTTP/1.0"', '"GET /geekery/find-that-lost-screen-session.html HTTP/1.0"', '"GET /blog/geekery/tsawm-window-manager-project.html HTTP/1.0"', '"GET /blog/geekery/eventdb-ideas.html HTTP/1.0"', '"GET /blog/tags/barcampstanford HTTP/1.0"', '"GET /blog/tags/pcre HTTP/1.0"', '"GET /blog/tags/tales-of-olden-time HTTP/1.0"', '"GET /blog/tags/c++ HTTP/1.0"', '"GET /blog/geekery/grok-gets-more-ridiculous.html HTTP/1.0"', '"GET /blog/tags/shdh HTTP/1.0"', '"GET /blog/tags/barcampnyc HTTP/1.0"', '"GET /blog/tags/fex HTTP/1.0"', '"GET /blog/tags/sed HTTP/1.0"', '"GET /blog/tags/xlib HTTP/1.0"']
#
#
#  Client ('207.241.237.227', '"Mozilla/5.0 (compatible; archive.org_bot +http://www.archive.org/details/archive.org_bot)"') accessed these pages
#  ['"GET /blog/geekery/soekris-gpio.html HTTP/1.0"', '"GET /blog/tags/soekris HTTP/1.0"', '"GET /blog/tags/hack HTTP/1.0"', '"GET /blog/geekery/asus-k8n-dl-sata-boot-linux.html HTTP/1.0"', '"GET /blog/tags/egg HTTP/1.0"', '"GET /blog/tags/security HTTP/1.0"', '"GET /blog/tags/releases HTTP/1.0"', '"GET /blog/tags/defcon15 HTTP/1.0"', '"GET /blog/geekery/boost-xpressive-testing.html HTTP/1.0"', '"GET /projects/pam_captcha/ HTTP/1.0"', '"GET /blog/tags/hackday06 HTTP/1.0"', '"GET /blog/tags/music HTTP/1.0"', '"GET /blog/tags/barcampsf HTTP/1.0"', '"GET /blog/articles/week-of-unix-tools/day-3-awk.html HTTP/1.0"', '"GET /blog/static/about.html HTTP/1.0"']
#
#
#  Client ('91.177.205.119', '"Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; WOW64; Trident/6.0)"') accessed these pages
#  ['"GET /blog/geekery/xvfb-firefox.html HTTP/1.1"', '"GET /reset.css HTTP/1.1"', '"GET /style2.css HTTP/1.1"', '"GET /images/jordan-80.png HTTP/1.1"', '"GET /images/web/2009/banner.png HTTP/1.1"']
#
#
#  Client ('91.177.205.119', '"Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; Win64; x64; Trident/6.0)"') accessed these pages
#  ['"GET /favicon.ico HTTP/1.1"']
#
#
#  Client ('207.241.237.228', '"Mozilla/5.0 (compatible; archive.org_bot +http://www.archive.org/details/archive.org_bot)"') accessed these pages
#  ['"GET /blog/tags/defcon HTTP/1.0"', '"GET /?page=1 HTTP/1.0"', '"GET /files/blogposts/20101209/fullheight.html HTTP/1.0"', '"GET /blog/geekery/xdotool-2.20100623.html HTTP/1.0"', '"GET /blog/tags/glob HTTP/1.0"', '"GET /blog/tags/motherboards HTTP/1.0"', '"GET /blog/tags/virtualization HTTP/1.0"', '"GET /blog/tags/upgrades HTTP/1.0"', '"GET /blog/geekery/fedora-9-subversion-1.5.html HTTP/1.0"', '"GET /blog/geekery/firewall-reset-for-testing.html HTTP/1.0"', '"GET /projects/kioskweb/demo/keyboard.html HTTP/1.0"', '"GET /blog/geekery/222.html HTTP/1.0"', '"GET /blog/tags/travel HTTP/1.0"', '"GET /blog/tags/shmoocon HTTP/1.0"', '"GET /blog/tags/keyboard HTTP/1.0"', '"GET /blog/site/sitemove.html HTTP/1.0"']
#
#
#  Client ('207.241.237.101', '"Mozilla/5.0 (compatible; archive.org_bot +http://www.archive.org/details/archive.org_bot)"') accessed these pages
#  ['"GET /blog/tags/regex HTTP/1.0"', '"GET /files/blogposts/20080107/oniguruma_named_captures.c HTTP/1.0"', '"GET /blog/geekery/xdotool-1.20100227.html HTTP/1.0"', '"GET /blog/tags/xorg HTTP/1.0"', '"GET /blog/geekery/find-that-lost-screen-session.html HTTP/1.0"', '"GET /blog/tags/centos HTTP/1.0"', '"GET /blog/geekery/mini-freebsd-script.html HTTP/1.0"', '"GET /blog/geekery/year-in-review-2006.html HTTP/1.0"', '"GET /blog/geekery/wsj-feature.html HTTP/1.0"', '"GET /blog/geekery/splitting-large-logs.html HTTP/1.0"', '"GET /blog/geekery/simple-mysql-slave-id-scaling.html HTTP/1.0"', '"GET /blog/geekery/migration-to-googlecode.html HTTP/1.0"', '"GET /blog/geekery/barcamp-rochester3.html HTTP/1.0"', '"GET /blog/articles/ppp-over-ssh/main.html HTTP/1.0"', '"GET /blog/tags/release?page=2 HTTP/1.0"', '"GET /robots.txt HTTP/1.0"', '"GET /blog/articles/week-of-unix-tools/day-2-cut-and-paste.html HTTP/1.0"']
#
#
#  Client ('87.169.99.232', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/32.0.1700.107 Safari/537.36"') accessed these pages
#  ['"GET /presentations/puppet-at-loggly/puppet-at-loggly.pdf.html HTTP/1.1"']
#
#
#  Client ('209.85.238.199', '"Feedfetcher-Google; (+http://www.google.com/feedfetcher.html; 3 subscribers; feed-id=14171215010336145331)"') accessed these pages
#  ['"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"']
#
#
#  Client ('209.85.238.199', '"Feedfetcher-Google; (+http://www.google.com/feedfetcher.html; 1 subscribers; feed-id=11390274670024826467)"') accessed these pages
#  ['"GET /test.xml HTTP/1.1"', '"GET /test.xml HTTP/1.1"', '"GET /test.xml HTTP/1.1"', '"GET /test.xml HTTP/1.1"', '"GET /test.xml HTTP/1.1"', '"GET /test.xml HTTP/1.1"', '"GET /test.xml HTTP/1.1"', '"GET /test.xml HTTP/1.1"', '"GET /test.xml HTTP/1.1"']
#
#
#  Client ('81.220.24.207', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_1) AppleWebKit/537.73.11 (KHTML, like Gecko) Version/7.0.1 Safari/537.73.11"') accessed these pages
#  ['"GET /blog/geekery/ssl-latency.html HTTP/1.1"', '"GET /reset.css HTTP/1.1"', '"GET /images/jordan-80.png HTTP/1.1"', '"GET /style2.css HTTP/1.1"', '"GET /images/web/2009/banner.png HTTP/1.1"', '"GET /favicon.ico HTTP/1.1"']
#
#
#  Client ('218.30.103.62', '"Sogou web spider/4.0(+http://www.sogou.com/docs/help/webmasters.htm#07)"') accessed these pages
#  ['"GET /robots.txt HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /projects/fex/ HTTP/1.1"', '"GET /projects/xdotool/xdotool.xhtml HTTP/1.1"', '"GET /blog/geekery/c-vs-python-bdb.html HTTP/1.1"', '"GET /blog/productivity/better-zsh-xterm-title-fix.html HTTP/1.1"', '"GET /blog/geekery/xvfb-firefox.html HTTP/1.1"', '"GET /blog/geekery/puppet-facts-into-mcollective.html HTTP/1.1"', '"GET /blog/geekery/jquery-interface-puffer.html%20target= HTTP/1.1"', '"GET /blog/geekery/ec2-reserved-vs-ondemand.html HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /blog/geekery/debugging-java-performance.html HTTP/1.1"', '"GET /blog HTTP/1.1"', '"GET /projects/xboxproxy HTTP/1.1"', '"GET /projects/xboxproxy/ HTTP/1.1"']
#
#
#  Client ('74.125.40.20', '"FeedBurner/1.0 (http://www.FeedBurner.com)"') accessed these pages
#  ['"GET /?flav=rss20 HTTP/1.1"', '"GET /?flav=rss20 HTTP/1.1"']
#
#
#  Client ('71.212.224.97', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/32.0.1700.107 Safari/537.36"') accessed these pages
#  ['"GET /projects/xdotool/ HTTP/1.1"', '"GET /reset.css HTTP/1.1"', '"GET /style2.css HTTP/1.1"', '"GET /images/jordan-80.png HTTP/1.1"', '"GET /images/web/2009/banner.png HTTP/1.1"']
#
#
#  Client ('108.174.55.234', '"-"') accessed these pages
#  ['"GET /?flav=rss20 HTTP/1.1"', '"GET /?flav=rss20 HTTP/1.1"', '"GET /?flav=rss20 HTTP/1.1"', '"GET /?flav=rss20 HTTP/1.1"', '"GET /?flav=rss20 HTTP/1.1"', '"GET /?flav=rss20 HTTP/1.1"', '"GET /?flav=rss20 HTTP/1.1"', '"GET /?flav=rss20 HTTP/1.1"', '"GET /?flav=rss20 HTTP/1.1"', '"GET /?flav=rss20 HTTP/1.1"', '"GET /?flav=rss20 HTTP/1.1"', '"GET /?flav=rss20 HTTP/1.1"', '"GET /?flav=rss20 HTTP/1.1"', '"GET /?flav=rss20 HTTP/1.1"', '"GET /?flav=rss20 HTTP/1.1"', '"GET /?flav=rss20 HTTP/1.1"', '"GET /?flav=rss20 HTTP/1.1"', '"GET /?flav=rss20 HTTP/1.1"', '"GET /?flav=rss20 HTTP/1.1"', '"GET /?flav=rss20 HTTP/1.1"', '"GET /?flav=rss20 HTTP/1.1"', '"GET /?flav=rss20 HTTP/1.1"', '"GET /?flav=rss20 HTTP/1.1"']
#
#
#  Client ('121.107.188.202', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/32.0.1700.107 Safari/537.36"') accessed these pages
#  ['"GET /presentations/logstash-monitorama-2013/images/kibana-dashboard3.png HTTP/1.1"']
#
#
#  Client ('198.46.149.143', '"Tiny Tiny RSS/1.11 (http://tt-rss.org/)"') accessed these pages
#  ['"GET /blog/geekery/disabling-battery-in-ubuntu-vms.html?utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+semicomplete%2Fmain+%28semicomplete.com+-+Jordan+Sissel%29 HTTP/1.1"', '"GET /blog/geekery/solving-good-or-bad-problems.html?utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+semicomplete%2Fmain+%28semicomplete.com+-+Jordan+Sissel%29 HTTP/1.1"', '"GET /blog/geekery/disabling-battery-in-ubuntu-vms.html?utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+semicomplete%2Fmain+%28semicomplete.com+-+Jordan+Sissel%29 HTTP/1.1"', '"GET /blog/geekery/solving-good-or-bad-problems.html?utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+semicomplete%2Fmain+%28semicomplete.com+-+Jordan+Sissel%29 HTTP/1.1"', '"GET /blog/geekery/disabling-battery-in-ubuntu-vms.html?utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+semicomplete%2Fmain+%28semicomplete.com+-+Jordan+Sissel%29 HTTP/1.1"', '"GET /blog/geekery/solving-good-or-bad-problems.html?utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+semicomplete%2Fmain+%28semicomplete.com+-+Jordan+Sissel%29 HTTP/1.1"', '"GET /blog/geekery/disabling-battery-in-ubuntu-vms.html?utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+semicomplete%2Fmain+%28semicomplete.com+-+Jordan+Sissel%29 HTTP/1.1"', '"GET /blog/geekery/solving-good-or-bad-problems.html?utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+semicomplete%2Fmain+%28semicomplete.com+-+Jordan+Sissel%29 HTTP/1.1"', '"GET /blog/geekery/disabling-battery-in-ubuntu-vms.html?utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+semicomplete%2Fmain+%28semicomplete.com+-+Jordan+Sissel%29 HTTP/1.1"', '"GET /blog/geekery/solving-good-or-bad-problems.html?utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+semicomplete%2Fmain+%28semicomplete.com+-+Jordan+Sissel%29 HTTP/1.1"', '"GET /blog/geekery/disabling-battery-in-ubuntu-vms.html?utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+semicomplete%2Fmain+%28semicomplete.com+-+Jordan+Sissel%29 HTTP/1.1"', '"GET /blog/geekery/solving-good-or-bad-problems.html?utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+semicomplete%2Fmain+%28semicomplete.com+-+Jordan+Sissel%29 HTTP/1.1"', '"GET /blog/geekery/disabling-battery-in-ubuntu-vms.html?utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+semicomplete%2Fmain+%28semicomplete.com+-+Jordan+Sissel%29 HTTP/1.1"', '"GET /blog/geekery/solving-good-or-bad-problems.html?utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+semicomplete%2Fmain+%28semicomplete.com+-+Jordan+Sissel%29 HTTP/1.1"', '"GET /blog/geekery/disabling-battery-in-ubuntu-vms.html?utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+semicomplete%2Fmain+%28semicomplete.com+-+Jordan+Sissel%29 HTTP/1.1"', '"GET /blog/geekery/solving-good-or-bad-problems.html?utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+semicomplete%2Fmain+%28semicomplete.com+-+Jordan+Sissel%29 HTTP/1.1"', '"GET /blog/geekery/disabling-battery-in-ubuntu-vms.html?utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+semicomplete%2Fmain+%28semicomplete.com+-+Jordan+Sissel%29 HTTP/1.1"', '"GET /blog/geekery/solving-good-or-bad-problems.html?utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+semicomplete%2Fmain+%28semicomplete.com+-+Jordan+Sissel%29 HTTP/1.1"', '"GET /blog/geekery/disabling-battery-in-ubuntu-vms.html?utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+semicomplete%2Fmain+%28semicomplete.com+-+Jordan+Sissel%29 HTTP/1.1"', '"GET /blog/geekery/solving-good-or-bad-problems.html?utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+semicomplete%2Fmain+%28semicomplete.com+-+Jordan+Sissel%29 HTTP/1.1"', '"GET /blog/geekery/disabling-battery-in-ubuntu-vms.html?utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+semicomplete%2Fmain+%28semicomplete.com+-+Jordan+Sissel%29 HTTP/1.1"', '"GET /blog/geekery/solving-good-or-bad-problems.html?utm_source=feedburner&utm_medium=feed&utm_campa ...
#
#
#  Client ('86.1.76.62', '"Mozilla/5.0 (X11; Linux x86_64; rv:24.0) Gecko/20140205 Firefox/24.0 Iceweasel/24.3.0"') accessed these pages
#  ['"GET /projects/xdotool/ HTTP/1.1"', '"GET /reset.css HTTP/1.1"', '"GET /style2.css HTTP/1.1"', '"GET /favicon.ico HTTP/1.1"', '"GET /images/jordan-80.png HTTP/1.1"', '"GET /images/web/2009/banner.png HTTP/1.1"']
#
#
#  Client ('66.249.73.135', '"DoCoMo/2.0 N905i(c100;TB;W24H16) (compatible; Googlebot-Mobile/2.1; +http://www.google.com/bot.html)"') accessed these pages
#  ['"GET /blog/tags/bdb HTTP/1.1"', '"GET /projects/xdotool/xdotool.xhtml HTTP/1.1"', '"GET /scripts/python/ HTTP/1.1"', '"GET /scripts/python/wrap.backup/ HTTP/1.1"', '"GET /blog/tags/rfc%20failure HTTP/1.1"', '"GET / HTTP/1.1"']
#
#
#  Client ('107.170.41.69', '"Feedbin - 1 subscribers"') accessed these pages
#  ['"GET /?flav=atom HTTP/1.1"', '"GET /?flav=atom HTTP/1.1"', '"GET /?flav=atom HTTP/1.1"', '"GET /?flav=atom HTTP/1.1"', '"GET /?flav=atom HTTP/1.1"', '"GET /?flav=atom HTTP/1.1"', '"GET /?flav=atom HTTP/1.1"', '"GET /?flav=atom HTTP/1.1"', '"GET /?flav=atom HTTP/1.1"', '"GET /?flav=atom HTTP/1.1"']
#
#
#  Client ('208.115.111.72', '"Mozilla/5.0 (compatible; Ezooms/1.0; help@moz.com)"') accessed these pages
#  ['"GET /blog/rants/fedora-yum.html HTTP/1.1"', '"GET /blog/tags/grok HTTP/1.1"', '"GET /blog/tags/is%20it%20done%20yet HTTP/1.1"', '"GET /blog/tags/statistics HTTP/1.1"', '"GET /blog/tags/subversion HTTP/1.1"', '"GET /blog/web/194.html HTTP/1.1"', '"GET /files/blogposts/20070901/?C=D;O=A HTTP/1.1"', '"GET /files/blogposts/20080109/boost_xpressive_test.cpp HTTP/1.1"', '"GET /files/blogposts/20090520/ HTTP/1.1"', '"GET /files/fastsplit/?C=M;O=D HTTP/1.1"', '"GET /files/xdotool/docs/man/?C=M;O=D HTTP/1.1"', '"GET /scripts/python/wrap/?C=N;O=D HTTP/1.1"', '"GET /files/images/?C=S;O=D HTTP/1.1"', '"GET /files/blogposts/20080611/ HTTP/1.1"', '"GET /files/logstash/?C=D;O=D HTTP/1.1"', '"GET /presentations/hackday06/ HTTP/1.1"', '"GET /scripts/grok-py-test/ HTTP/1.1"', '"GET /?N=A&page=21 HTTP/1.1"', '"GET /blog/geekery/oniguruma-named-capture-example.html?commentlimit=0 HTTP/1.1"', '"GET /blog/geekery/ssh-key-invalid-hack.html?commentlimit=0 HTTP/1.1"', '"GET /blog/geekery/server-side-javascript.html HTTP/1.1"', '"GET /blog/geekery/yahoo-hackday-08.html HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /blog/geekery/grok-like-grep.html HTTP/1.1"', '"GET /files/blogposts/20101112/?C=D;O=A HTTP/1.1"', '"GET /files/xdotool/docs/html/index.html HTTP/1.1"', '"GET /files/xdotool/docs/man/man3/xdo.3 HTTP/1.1"', '"GET /scripts/?C=M;O=A HTTP/1.1"', '"GET /scripts/grok-py-test/main.py HTTP/1.1"', '"GET /blog/geekery/184.html HTTP/1.1"', '"GET /blog/geekery/211.html HTTP/1.1"', '"GET /blog/geekery/installing-windows-8-consumer-preview.html HTTP/1.1"', '"GET /blog/geekery/thoughts-on-raid.html HTTP/1.1"', '"GET /blog/projects/pam_captcha/main.html HTTP/1.1"', '"GET /blog/tags/rants HTTP/1.1"', '"GET /blog/tags/web%20scraping HTTP/1.1"', '"GET /files/?C=S;O=A HTTP/1.1"', '"GET /files/rubygems615/?C=S;O=A HTTP/1.1"', '"GET /projects/xmlpresenter/ HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /blog/tags/freebsd?page=3 HTTP/1.1"', '"GET /blog/tags/travel?page=2 HTTP/1.1"', '"GET /files/blogposts/20070826/?C=N;O=D HTTP/1.1"', '"GET /files/logstash/?C=N;O=A HTTP/1.1"', '"GET /files/xdotool/docs HTTP/1.1"', '"GET /scripts/python/wrap.backup/main.py HTTP/1.1"', '"GET /scripts/xclipsync HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /files/blogposts/20080423/dcache.sh HTTP/1.1"', '"GET /files/logstash/?C=S;O=A HTTP/1.1"', '"GET /files/pp/?C=D;O=A HTTP/1.1"', '"GET /files/xmlpresenter/?C=D;O=D HTTP/1.1"', '"GET /presentations/logstash-puppetconf-2012/images/?C=M;O=A HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /blog/geekery/freebsd-ports-master-sites-sorting.html HTTP/1.1"', '"GET /files/blogposts/20070617/navmacro.c HTTP/1.1"', '"GET /files/blogposts/20071206/?C=M;O=A HTTP/1.1"', '"GET /files/firefox-urledit/?C=D;O=D HTTP/1.1"', '"GET /files/winmgr/?C=N;O=A HTTP/1.1"', '"GET /scripts/?C=M;O=D HTTP/1.1"', '"GET /scripts/fastest_sites.py HTTP/1.1"', '"GET /files/xdotool/docs/html/functions.html HTTP/1.1"', '"GET /files/blogposts/20080310/?C=S;O=A HTTP/1.1"', '"GET /files/java-chatclient/?C=S;O=D HTTP/1.1"', '"GET /files/xdotool/docs/html/xdo_8h.html HTTP/1.1"', '"GET /?page=25 HTTP/1.1"', '"GET /scripts/python/wrap/?C=D;O=A HTTP/1.1"', '"GET /blog/2007/Aug/11 HTTP/1.1"', '"GET /blog/projects/fex/main.html HTTP/1.1"', '"GET /blog/projects/xmlpresenter/main.html HTTP/1.1"', '"GET /blog/tags/freebsd?page=1 HTTP/1.1"', '"GET /blog/tags/grok?page=1 HTTP/1.1"', '"GET /blog/tags/site HTTP/1.1"', '"GET /blog/tags/sqlite HTTP/1.1"', '"GET /blog/tags/sysadvent2010 HTTP/1.1"', '"GET /blog/tools/week-of-unix-day-1.html HTTP/1.1"']
#
#
#  Client ('50.180.79.170', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10.5; rv:16.0) Gecko/20100101 Firefox/16.0"') accessed these pages
#  ['"GET /favicon.ico HTTP/1.1"', '"GET /favicon.ico HTTP/1.1"']
#
#
#  Client ('105.235.130.196', '"Dalvik/1.6.0 (Linux; U; Android 4.1.2; GT-S5282 Build/JZO54K)"') accessed these pages
#  ['"GET /images/googledotcom.png HTTP/1.1"']
#
#
#  Client ('174.37.205.76', '"Mozilla/5.0 (X11; U; Linux x86_64; en-US; rv:1.9.0.19; aggregator:Spinn3r (Spinn3r 3.1); http://spinn3r.com/robot) Gecko/2010040121 Firefox/3.0.19"') accessed these pages
#  ['"GET /blog HTTP/1.1"']
#
#
#  Client ('54.255.13.204', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10.8; rv:27.0) Gecko/20100101 Firefox/27.0"') accessed these pages
#  ['"GET /articles/ssh-security/ HTTP/1.1"', '"GET /reset.css HTTP/1.1"', '"GET /style2.css HTTP/1.1"', '"GET /favicon.ico HTTP/1.1"', '"GET /images/jordan-80.png HTTP/1.1"', '"GET /images/web/2009/banner.png HTTP/1.1"']
#
#
#  Client ('105.235.130.196', '"Mozilla/5.0 (Linux; Android 4.1.2; GT-S5282 Build/JZO54K) AppleWebKit/537.31 (KHTML, like Gecko) Chrome/26.0.1410.58 Mobile Safari/537.31"') accessed these pages
#  ['"GET /blog/tags/X11 HTTP/1.1"', '"GET /reset.css HTTP/1.1"', '"GET /style2.css HTTP/1.1"', '"GET /images/jordan-80.png HTTP/1.1"', '"GET /images/web/2009/banner.png HTTP/1.1"']
#
#
#  Client ('134.76.249.10', '"Mozilla/5.0 (X11; Linux x86_64; rv:26.0) Gecko/20100101 Firefox/26.0"') accessed these pages
#  ['"GET /projects/xdotool/ HTTP/1.1"', '"GET /reset.css HTTP/1.1"', '"GET /style2.css HTTP/1.1"', '"GET /favicon.ico HTTP/1.1"', '"GET /images/jordan-80.png HTTP/1.1"', '"GET /images/web/2009/banner.png HTTP/1.1"', '"GET /projects/xdotool HTTP/1.1"', '"GET /projects/xdotool/ HTTP/1.1"']
#
#
#  Client ('68.184.202.186', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/32.0.1700.107 Safari/537.36"') accessed these pages
#  ['"GET /projects/xpathtool/ HTTP/1.1"', '"GET /reset.css HTTP/1.1"', '"GET /images/jordan-80.png HTTP/1.1"', '"GET /style2.css HTTP/1.1"', '"GET /images/web/2009/banner.png HTTP/1.1"', '"GET /favicon.ico HTTP/1.1"']
#
#
#  Client ('24.233.162.179', '"Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:25.0) Gecko/20100101 Firefox/25.0"') accessed these pages
#  ['"GET /favicon.ico HTTP/1.1"']
#
#
#  Client ('123.125.71.117', '"Mozilla/5.0 (compatible; Baiduspider/2.0; +http://www.baidu.com/search/spider.html)"') accessed these pages
#  ['"GET / HTTP/1.1"']
#
#
#  Client ('220.181.108.153', '"Mozilla/5.0 (compatible; Baiduspider/2.0; +http://www.baidu.com/search/spider.html)"') accessed these pages
#  ['"GET / HTTP/1.1"']
#
#
#  Client ('65.19.138.34', '"Feedly/1.0 (+http://www.feedly.com/fetcher.html; like FeedFetcher-Google)"') accessed these pages
#  ['"GET / HTTP/1.1"', '"GET /blog/tags/puppet?flav=rss20 HTTP/1.1"', '"GET /blog/tags/firefox?flav=rss20 HTTP/1.1"']
#
#
#  Client ('97.116.185.190', '"Mozilla/5.0 (Windows NT 5.2; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/32.0.1700.107 Safari/537.36"') accessed these pages
#  ['"GET /articles/dynamic-dns-with-dhcp/ HTTP/1.1"', '"GET /reset.css HTTP/1.1"', '"GET /style2.css HTTP/1.1"', '"GET /images/jordan-80.png HTTP/1.1"', '"GET /images/web/2009/banner.png HTTP/1.1"', '"GET /favicon.ico HTTP/1.1"']
#
#
#  Client ('5.255.72.168', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10.7; rv:21.0) Gecko/20100101 Firefox/21.0"') accessed these pages
#  ['"GET / HTTP/1.0"', '"GET /blog/geekery/installing-windows-8-consumer-preview.html HTTP/1.0"']
#
#
#  Client ('5.102.173.71', '"Mozilla/5.0 (compatible; MojeekBot/0.6; http://www.mojeek.com/bot.html)"') accessed these pages
#  ['"GET /robots.txt HTTP/1.1"', '"GET /projects/xdotool/ HTTP/1.1"']
#
#
#  Client ('208.91.156.11', '"Chef Client/10.18.2 (ruby-1.9.3-p327; ohai-6.16.0; x86_64-linux; +http://opscode.com)"') accessed these pages
# ...
#
#
#  Client ('173.232.105.27', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10.7; rv:21.0) Gecko/20100101 Firefox/21.0"') accessed these pages
#  ['"GET / HTTP/1.0"', '"GET /articles/ssh-security/ HTTP/1.0"']
#
#
#  Client ('180.76.5.144', '"Mozilla/5.0 (compatible; Baiduspider/2.0; +http://www.baidu.com/search/spider.html)"') accessed these pages
#  ['"GET /blog/tools/week-of-unix-pipe-friendly-tools.html?commentlimit=0 HTTP/1.1"']
#
#
#  Client ('83.222.46.173', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/32.0.1700.107 Safari/537.36"') accessed these pages
#  ['"GET /presentations/logstash-scale11x/images/logstash.png HTTP/1.1"']
#
#
#  Client ('88.134.8.254', '"Mozilla/5.0 (X11; Linux x86_64; rv:27.0) Gecko/20100101 Firefox/27.0"') accessed these pages
#  ['"GET /favicon.ico HTTP/1.1"']
#
#
#  Client ('83.105.90.45', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8) AppleWebKit/534.59.10 (KHTML, like Gecko) Version/5.1.9 Safari/534.59.10"') accessed these pages
#  ['"GET /projects/xdotool/ HTTP/1.1"', '"GET /reset.css HTTP/1.1"', '"GET /style2.css HTTP/1.1"', '"GET /images/jordan-80.png HTTP/1.1"', '"GET /images/web/2009/banner.png HTTP/1.1"', '"GET /favicon.ico HTTP/1.1"']
#
#
#  Client ('66.249.81.91', '"Mozilla/5.0 (Windows NT 6.1; rv:6.0) Gecko/20110814 Firefox/6.0 Google favicon"') accessed these pages
#  ['"GET /favicon.ico HTTP/1.1"', '"GET /projects/xdotool/xdotool.xhtml HTTP/1.1"', '"GET / HTTP/1.1"']
#
#
#  Client ('69.171.237.10', '"facebookexternalhit/1.1 (+http://www.facebook.com/externalhit_uatext.php)"') accessed these pages
#  ['"GET /presentations/logstash-puppetconf-2012/images/office-space-printer-beat-down-gif.gif HTTP/1.1"']
#
#
#  Client ('69.171.237.9', '"facebookexternalhit/1.0 (+http://www.facebook.com/externalhit_uatext.php)"') accessed these pages
#  ['"GET /presentations/logstash-puppetconf-2012/images/office-space-printer-beat-down-gif.gif HTTP/1.1"']
#
#
#  Client ('131.253.24.32', '"Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; Trident/5.0;  WOW64;  Trident/5.0)"') accessed these pages
#  ['"GET /blog/geekery/fpm.html HTTP/1.1"', '"GET /reset.css HTTP/1.1"', '"GET /style2.css HTTP/1.1"']
#
#
#  Client ('86.130.160.107', '"Mozilla/5.0 (X11; Linux x86_64; rv:17.0) Gecko/20100101 Firefox/17.0"') accessed these pages
#  ['"GET /projects/xdotool/xdotool.xhtml HTTP/1.1"', '"GET /favicon.ico HTTP/1.1"', '"GET /projects/xdotool/ HTTP/1.1"', '"GET /reset.css HTTP/1.1"', '"GET /style2.css HTTP/1.1"', '"GET /images/jordan-80.png HTTP/1.1"', '"GET /images/web/2009/banner.png HTTP/1.1"', '"GET /projects/xdotool HTTP/1.1"', '"GET /projects/xdotool/ HTTP/1.1"']
#
#
#  Client ('178.48.154.212', '"Xenu Link Sleuth/1.3.8"') accessed these pages
#  ['"HEAD /blog HTTP/1.1"']
#
#
#  Client ('180.153.236.122', '"Mozilla/5.0 (Windows; U; Windows NT 5.1; zh-CN; )  Firefox/1.5.0.11; 360Spider"') accessed these pages
#  ['"GET /articles/ssh-security/ HTTP/1.1"']
#
#
#  Client ('41.99.29.14', '"Mozilla/5.0 (Linux; U; Android 2.3.4; fr-fr; LG-P698 Build/GRJ22) AppleWebKit/533.1 (KHTML, like Gecko) Version/4.0 Mobile Safari/533.1 MMS/LG-Android-MMS-V1.0/1.2"') accessed these pages
#  ['"GET /images/googledotcom.png HTTP/1.1"']
#
#
#  Client ('84.60.79.43', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_1) AppleWebKit/537.73.11 (KHTML, like Gecko) Version/7.0.1 Safari/537.73.11"') accessed these pages
#  ['"GET /blog/geekery/shebang-fix.html HTTP/1.1"', '"GET /reset.css HTTP/1.1"', '"GET /style2.css HTTP/1.1"', '"GET /images/jordan-80.png HTTP/1.1"', '"GET /images/web/2009/banner.png HTTP/1.1"', '"GET /favicon.ico HTTP/1.1"']
#
#
#  Client ('98.202.182.168', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/32.0.1700.107 Safari/537.36"') accessed these pages
#  ['"GET /presentations/logstash-scale11x/images/ahhh___rage_face_by_samusmmx-d5g5zap.png HTTP/1.1"']
#
#
#  Client ('71.191.158.163', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_5) AppleWebKit/537.73.11 (KHTML, like Gecko) Version/6.1.1 Safari/537.73.11"') accessed these pages
#  ['"GET /projects/xdotool/ HTTP/1.1"', '"GET /reset.css HTTP/1.1"', '"GET /style2.css HTTP/1.1"', '"GET /images/jordan-80.png HTTP/1.1"', '"GET /images/web/2009/banner.png HTTP/1.1"', '"GET /favicon.ico HTTP/1.1"']
#
#
#  Client ('54.219.33.174', '"Digg Feed Fetcher 1.0 (Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_1) AppleWebKit/534.48.3 (KHTML, like Gecko) Version/5.1 Safari/534.48.3)"') accessed these pages
#  ['"GET /?flav=atom HTTP/1.1"']
#
#
#  Client ('180.76.6.150', '"Mozilla/5.0 (compatible; Baiduspider/2.0; +http://www.baidu.com/search/spider.html)"') accessed these pages
#  ['"GET /blog/articles/week-of-unix-tools/day-5-xargs.html HTTP/1.1"']
#
#
#  Client ('37.137.150.253', '"Mozilla/5.0 (Linux; U; Android 4.1.2; fa-fa; GT-I9082 Build/JZO54K) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.0 Mobile Safari/534.30"') accessed these pages
#  ['"GET /images/googledotcom.png HTTP/1.1"']
#
#
#  Client ('108.170.215.93', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/34.0.1843.0 Safari/537.36"') accessed these pages
#  ['"GET / HTTP/1.1"', '"GET /reset.css HTTP/1.1"', '"GET /style2.css HTTP/1.1"', '"GET /images/jordan-80.png HTTP/1.1"']
#
#
#  Client ('84.75.200.115', '"Mozilla/5.0 (Windows NT 6.3; WOW64; rv:27.0) Gecko/20100101 Firefox/27.0"') accessed these pages
#  ['"GET /articles/ppp-over-ssh/ HTTP/1.1"', '"GET /reset.css HTTP/1.1"', '"GET /style2.css HTTP/1.1"', '"GET /favicon.ico HTTP/1.1"', '"GET /images/jordan-80.png HTTP/1.1"', '"GET /articles/ppp-over-ssh/pppoverssh.png HTTP/1.1"', '"GET /images/web/2009/banner.png HTTP/1.1"']
#
#
#  Client ('78.157.154.210', '"Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:27.0) Gecko/20100101 Firefox/27.0"') accessed these pages
#  ['"GET /files/xdotool/docs/ HTTP/1.1"', '"GET /icons/blank.gif HTTP/1.1"', '"GET /icons/back.gif HTTP/1.1"', '"GET /icons/folder.gif HTTP/1.1"', '"GET /favicon.ico HTTP/1.1"', '"GET /files/xdotool/docs/html/ HTTP/1.1"', '"GET /files/xdotool/docs/html/tabs.css HTTP/1.1"', '"GET /files/xdotool/docs/html/search/search.css HTTP/1.1"', '"GET /files/xdotool/docs/html/search/search.js HTTP/1.1"', '"GET /files/xdotool/docs/html/doxygen.css HTTP/1.1"', '"GET /files/xdotool/docs/html/search/search.png HTTP/1.1"', '"GET /files/xdotool/docs/html/search/close.png HTTP/1.1"', '"GET /files/xdotool/docs/html/doxygen.png HTTP/1.1"', '"GET /files/xdotool/docs/html/tab_b.gif HTTP/1.1"', '"GET /files/xdotool/docs/html/tab_r.gif HTTP/1.1"', '"GET /files/xdotool/docs/html/tab_l.gif HTTP/1.1"', '"GET /files/xdotool/docs/html/xdo_8h.html HTTP/1.1"']
#
#
#  Client ('157.55.32.109', '"Mozilla/5.0 (compatible; bingbot/2.0; +http://www.bing.com/bingbot.htm)"') accessed these pages
#  ['"GET /blog/2006/Dec/19 HTTP/1.1"', '"GET /robots.txt HTTP/1.1"']
#
#
#  Client ('74.125.40.21', '"FeedBurner/1.0 (http://www.FeedBurner.com)"') accessed these pages
#  ['"GET /?flav=rss20 HTTP/1.1"', '"GET /?flav=rss20 HTTP/1.1"', '"GET /?flav=rss20 HTTP/1.1"']
#
#
#  Client ('114.69.226.80', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/32.0.1700.107 Safari/537.36"') accessed these pages
#  ['"GET /articles/dynamic-dns-with-dhcp/ HTTP/1.1"', '"GET /reset.css HTTP/1.1"', '"GET /style2.css HTTP/1.1"', '"GET /images/jordan-80.png HTTP/1.1"', '"GET /images/web/2009/banner.png HTTP/1.1"', '"GET /favicon.ico HTTP/1.1"']
#
#
#  Client ('200.50.183.132', '"Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/31.0.1650.63 Safari/537.36"') accessed these pages
#  ['"GET /presentations/logstash-scale11x/images/ahhh___rage_face_by_samusmmx-d5g5zap.png HTTP/1.1"']
#
#
#  Client ('95.234.214.194', '"Mozilla/5.0 (Linux; U; Android 4.1.2; it-it; GT-P3100 Build/JZO54K) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.0 Safari/534.30"') accessed these pages
#  ['"GET /images/googledotcom.png HTTP/1.1"']
#
#
#  Client ('46.28.105.80', '"-"') accessed these pages
#  ['"GET /wordpress/wp-admin/ HTTP/1.1"']
#
#
#  Client ('180.76.5.74', '"Mozilla/5.0 (compatible; Baiduspider/2.0; +http://www.baidu.com/search/spider.html)"') accessed these pages
#  ['"GET /blog/tools/week-of-unix-pipe-friendly-tools.html HTTP/1.1"']
#
#
#  Client ('96.127.213.6', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/32.0.1700.107 Safari/537.36"') accessed these pages
#  ['"GET /projects/xdotool/xdotool.xhtml HTTP/1.1"', '"GET /favicon.ico HTTP/1.1"']
#
#
#  Client ('187.60.96.7', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10.7; rv:21.0) Gecko/20100101 Firefox/21.0"') accessed these pages
#  ['"GET / HTTP/1.0"', '"GET /blog/geekery/installing-windows-8-consumer-preview.html HTTP/1.0"']
#
#
#  Client ('180.76.5.214', '"Mozilla/5.0 (Windows NT 5.1; rv:6.0.2) Gecko/20100101 Firefox/6.0.2"') accessed these pages
#  ['"GET /images/logstash_OSCON.pdf HTTP/1.1"', '"GET /presentations/logstash-scale11x/logstash-scale11x.pdf HTTP/1.1"']
#
#
#  Client ('180.76.6.53', '"Mozilla/5.0 (Windows NT 5.1; rv:6.0.2) Gecko/20100101 Firefox/6.0.2"') accessed these pages
#  ['"GET /robots.txt HTTP/1.1"']
#
#
#  Client ('198.148.112.117', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10.7; rv:21.0) Gecko/20100101 Firefox/21.0"') accessed these pages
#  ['"GET /presentations/logstash-1/ HTTP/1.1"', '"GET /presentations/logstash-1/ HTTP/1.1"', '"GET /presentations/logstash-scale11x/ HTTP/1.1"', '"GET /kibana/ HTTP/1.1"']
#
#
#  Client ('62.245.76.5', '"Mozilla/5.0 (X11; Linux i686) AppleWebKit/536.11 (KHTML, like Gecko) Chrome/20.0.1132.57 Safari/536.11"') accessed these pages
#  ['"GET /projects/xdotool/xdotool.xhtml HTTP/1.1"', '"GET /favicon.ico HTTP/1.1"']
#
#
#  Client ('91.236.75.25', '"Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1; Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1) )"') accessed these pages
#  ['"GET / HTTP/1.1"']
#
#
#  Client ('82.38.225.83', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/32.0.1700.107 Safari/537.36"') accessed these pages
#  ['"GET /images/pimp.png HTTP/1.1"']
#
#
#  Client ('199.102.67.16', '"-"') accessed these pages
#  ['"GET /blog/wp-admin/ HTTP/1.1"']
#
#
#  Client ('107.170.40.200', '"Feedbin - 1 subscribers"') accessed these pages
#  ['"GET /?flav=atom HTTP/1.1"', '"GET /?flav=atom HTTP/1.1"', '"GET /?flav=atom HTTP/1.1"']
#
#
#  Client ('46.120.130.221', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/32.0.1700.107 Safari/537.36"') accessed these pages
#  ['"GET /favicon.ico HTTP/1.1"']
#
#
#  Client ('178.137.95.70', '"-"') accessed these pages
#  ['"GET /blog/geekery/jquery-formfill-v1.html HTTP/1.1"', '"GET /blog/tags/statistics HTTP/1.1"']
#
#
#  Client ('66.249.73.185', '"Googlebot-Image/1.0"') accessed these pages
#  ['"GET /presentations/logstash-puppetconf-2012/images/apache-negative-duration.png HTTP/1.1"', '"GET /presentations/logstash-puppetconf-2012/images/nagios-sms2.png HTTP/1.1"', '"GET /presentations/logstash-puppetconf-2012/images/psychoaxe.jpg HTTP/1.1"', '"GET /presentations/logstash-puppetconf-2012/images/xkcd-perl.png HTTP/1.1"', '"GET /presentations/logstash-scale11x/images/logstash.png HTTP/1.1"', '"GET /presentations/logstash-puppetconf-2012/images/nagios-sms1.png HTTP/1.1"', '"GET /presentations/logstash-puppetconf-2012/images/pc-load-letter.jpg HTTP/1.1"', '"GET /presentations/logstash-puppetconf-2012/images/xkcd-perlswing-many.png HTTP/1.1"', '"GET /presentations/logstash-puppetconf-2012/images/sysadvent.png HTTP/1.1"']
#
#
#  Client ('54.219.246.6', '"Digg Feed Fetcher 1.0 (Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_1) AppleWebKit/534.48.3 (KHTML, like Gecko) Version/5.1 Safari/534.48.3)"') accessed these pages
#  ['"GET /?flav=rss20 HTTP/1.1"', '"GET /?flav=atom HTTP/1.1"']
#
#
#  Client ('99.158.0.150', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/32.0.1700.102 Chrome/32.0.1700.102 Safari/537.36"') accessed these pages
#  ['"GET /articles/dynamic-dns-with-dhcp/ HTTP/1.1"', '"GET /reset.css HTTP/1.1"', '"GET /style2.css HTTP/1.1"', '"GET /images/jordan-80.png HTTP/1.1"', '"GET /images/web/2009/banner.png HTTP/1.1"', '"GET /favicon.ico HTTP/1.1"']
#
#
#  Client ('195.242.218.133', '"Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.0; .NET CLR 1.0.3705; .NET CLR 1.1.4322)"') accessed these pages
#  ['"GET /blog/geekery/ssl-latency.html HTTP/1.1"', '"GET /blog/geekery/ssl-latency.html HTTP/1.1"', '"GET /blog/geekery/ssl-latency.html HTTP/1.1"']
#
#
#  Client ('180.235.148.243', '"Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.2; SV1; .NET CLR 2.0.50727; InfoPath.1)"') accessed these pages
#  ['"GET /images/googledotcom.png HTTP/1.1"']
#
#
#  Client ('79.116.60.76', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10.7; rv:21.0) Gecko/20100101 Firefox/21.0"') accessed these pages
#  ['"GET /images/logstash_OSCON.pdf HTTP/1.0"']
#
#
#  Client ('78.73.74.252', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:27.0) Gecko/20100101 Firefox/27.0"') accessed these pages
#  ['"GET /images/ec2_m1large_cost.png HTTP/1.1"']
#
#
#  Client ('180.76.6.28', '"Mozilla/5.0 (compatible; Baiduspider/2.0; +http://www.baidu.com/search/spider.html)"') accessed these pages
#  ['"GET /blog/articles/dynamic-dns-with-dhcp/ HTTP/1.1"']
#
#
#  Client ('74.125.40.18', '"FeedBurner/1.0 (http://www.FeedBurner.com)"') accessed these pages
#  ['"GET /?flav=rss20 HTTP/1.1"']
#
#
#  Client ('195.44.196.178', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/32.0.1700.107 Safari/537.36"') accessed these pages
#  ['"GET /blog/geekery/ssl-latency.html HTTP/1.1"', '"GET /reset.css HTTP/1.1"', '"GET /style2.css HTTP/1.1"', '"GET /images/jordan-80.png HTTP/1.1"', '"GET /images/web/2009/banner.png HTTP/1.1"', '"GET /favicon.ico HTTP/1.1"']
#
#
#  Client ('87.219.103.122', '"Mozilla/5.0 (X11; U; Linux i686; es-ES; rv:1.9.0.8) Gecko/2009033100 Ubuntu/9.04 (jaunty) Firefox/3.0.8"') accessed these pages
#  ['"GET /projects/xdotool/xdotool.xhtml HTTP/1.1"', '"GET /favicon.ico HTTP/1.1"']
#
#
#  Client ('95.222.193.200', '"Mozilla/5.0 (Windows NT 6.1; WOW64; rv:27.0) Gecko/20100101 Firefox/27.0"') accessed these pages
#  ['"GET /favicon.ico HTTP/1.1"', '"GET /favicon.ico HTTP/1.1"']
#
#
#  Client ('199.189.248.95', '"-"') accessed these pages
#  ['"GET /wp-admin/ HTTP/1.1"']
#
#
#  Client ('54.242.155.74', '"Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10.6; en-US; rv:1.9.2) Gecko/20100115 Firefox/3.6 (FlipboardProxy/1.1; +http://flipboard.com/browserproxy)"') accessed these pages
#  ['"GET /presentations/ HTTP/1.1"']
#
#
#  Client ('81.56.9.191', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/30.0.1599.101 Safari/537.36"') accessed these pages
#  ['"GET /presentations/puppet-at-loggly/puppet-at-loggly.pdf.html HTTP/1.1"', '"GET /favicon.ico HTTP/1.1"']
#
#
#  Client ('69.234.185.154', '"Mozilla/5.0 (Windows NT 6.1; WOW64; rv:26.0) Gecko/20100101 Firefox/26.0"') accessed these pages
#  ['"GET /articles/dynamic-dns-with-dhcp/ HTTP/1.1"', '"GET /reset.css HTTP/1.1"', '"GET /style2.css HTTP/1.1"', '"GET /favicon.ico HTTP/1.1"', '"GET /images/jordan-80.png HTTP/1.1"', '"GET /images/web/2009/banner.png HTTP/1.1"']
#
#
#  Client ('86.220.101.19', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10.7; rv:21.0) Gecko/20100101 Firefox/21.0"') accessed these pages
#  ['"GET /presentations/logstash-puppetconf-2012/ HTTP/1.1"', '"GET /presentations/puppet-at-loggly/puppet-at-loggly.pdf.html HTTP/1.1"']
#
#
#  Client ('85.19.71.167', '"-"') accessed these pages
#  ['"GET /wp/wp-admin/ HTTP/1.1"']
#
#
#  Client ('186.22.52.72', '"Mozilla/5.0 (X11; Linux i686; rv:22.0) Gecko/20100101 Firefox/22.0"') accessed these pages
#  ['"GET /blog/tags/jquery%20mobile HTTP/1.1"', '"GET /reset.css HTTP/1.1"', '"GET /style2.css HTTP/1.1"', '"GET /favicon.ico HTTP/1.1"', '"GET /images/jordan-80.png HTTP/1.1"', '"GET /images/web/2009/banner.png HTTP/1.1"']
#
#
#  Client ('131.253.24.76', '"Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; Trident/5.0;  WOW64;  Trident/5.0)"') accessed these pages
#  ['"GET /blog/2007/Jan/31 HTTP/1.1"', '"GET /reset.css HTTP/1.1"', '"GET /style2.css HTTP/1.1"']

# %%
all_pages=[]
for i in Pages_accessed:
    all_pages.append(Pages_accessed[i])

# %% [markdown]
# ### Apriori

# %%
from apyori import apriori

# %%
association_rules = apriori(all_pages, min_support=0.1, min_confidence=0.5, min_lift=1, min_length=7)
association_results = list(association_rules)

# %%
support=[]
items=[]
rhs=[]
lhs=[]
con=[]
lift=[]
for i in association_results:
    support.append(i.support)
    items.append(i.items)
    rhs.append(i.ordered_statistics[0][1])
    lhs.append(i.ordered_statistics[0][0])
    con.append(i.ordered_statistics[0][2])
    lift.append(i.ordered_statistics[0][3])

# %%
df=pd.DataFrame({'Items':items,'Antecedent':lhs,'Precedent':rhs,'Support':support, 'Confidence':con,'Lift':lift})

# %%
df.head()
# Out:
#                                                Items  \
# 0  ("GET /favicon.ico HTTP/1.1", "GET /images/jor...
# 1  ("GET /favicon.ico HTTP/1.1", "GET /images/web...
# 2  ("GET /favicon.ico HTTP/1.1", "GET /reset.css ...
# 3  ("GET /favicon.ico HTTP/1.1", "GET /style2.css...
# 4  ("GET /images/jordan-80.png HTTP/1.1", "GET /i...
#
#                                Antecedent  \
# 0           ("GET /favicon.ico HTTP/1.1")
# 1           ("GET /favicon.ico HTTP/1.1")
# 2           ("GET /favicon.ico HTTP/1.1")
# 3           ("GET /favicon.ico HTTP/1.1")
# 4  ("GET /images/jordan-80.png HTTP/1.1")
#
#                                       Precedent  Support  Confidence      Lift
# 0        ("GET /images/jordan-80.png HTTP/1.1")    0.180    0.580645  2.592166
# 1  ("GET /images/web/2009/banner.png HTTP/1.1")    0.180    0.580645  2.639296
# 2                   ("GET /reset.css HTTP/1.1")    0.180    0.580645  2.524544
# 3                  ("GET /style2.css HTTP/1.1")    0.180    0.580645  2.502781
# 4  ("GET /images/web/2009/banner.png HTTP/1.1")    0.216    0.964286  4.383117

# %%
s_p=df[df['Support']>0.20].sort_values('Support',ascending=False)
for i,items in df.iterrows():
    # first index of the inner list
    # Contains base item and add item
    # pair = item[0]
    # items = [x for x in pair]
    # print(item[0])
    print("Rule: " + str(items['Antecedent']) + " -> " + str(items['Precedent']))
    #second index of the inner list
    print("Support: " + str(items['Support']))
    #third index of the list located at 0th
    #of the third index of the inner list
    print("Confidence: " + str(items['Confidence']))
    print("Lift: " + str(items['Lift']))
    print("=====================================")
# Out:
# Rule: frozenset({'"GET /favicon.ico HTTP/1.1"'}) -> frozenset({'"GET /images/jordan-80.png HTTP/1.1"'})
# Support: 0.18
# Confidence: 0.5806451612903225
# Lift: 2.592165898617511
# =====================================
# Rule: frozenset({'"GET /favicon.ico HTTP/1.1"'}) -> frozenset({'"GET /images/web/2009/banner.png HTTP/1.1"'})
# Support: 0.18
# Confidence: 0.5806451612903225
# Lift: 2.6392961876832843
# =====================================
# Rule: frozenset({'"GET /favicon.ico HTTP/1.1"'}) -> frozenset({'"GET /reset.css HTTP/1.1"'})
# Support: 0.18
# Confidence: 0.5806451612903225
# Lift: 2.5245441795231414
# =====================================
# Rule: frozenset({'"GET /favicon.ico HTTP/1.1"'}) -> frozenset({'"GET /style2.css HTTP/1.1"'})
# Support: 0.18
# Confidence: 0.5806451612903225
# Lift: 2.5027808676307
# =====================================
# Rule: frozenset({'"GET /images/jordan-80.png HTTP/1.1"'}) -> frozenset({'"GET /images/web/2009/banner.png HTTP/1.1"'})
# Support: 0.216
# Confidence: 0.9642857142857143
# Lift: 4.383116883116883
# =====================================
# Rule: frozenset({'"GET /images/jordan-80.png HTTP/1.1"'}) -> frozenset({'"GET /reset.css HTTP/1.1"'})
# Support: 0.214
# Confidence: 0.9553571428571428
# Lift: 4.153726708074534
# =====================================
# Rule: frozenset({'"GET /images/jordan-80.png HTTP/1.1"'}) -> frozenset({'"GET /style2.css HTTP/1.1"'})
# Support: 0.214
# Confidence: 0.9553571428571428
# Lift: 4.117918719211822
# =====================================
# Rule: frozenset({'"GET /images/web/2009/banner.png HTTP/1.1"'}) -> frozenset({'"GET /reset.css HTTP/1.1"'})
# Support: 0.212
# Confidence: 0.9636363636363636
# Lift: 4.189723320158103
# =====================================
# Rule: frozenset({'"GET /images/web/2009/banner.png HTTP/1.1"'}) -> frozenset({'"GET /style2.css HTTP/1.1"'})
# Support: 0.212
# Confidence: 0.9636363636363636
# Lift: 4.153605015673981
# =====================================
# Rule: frozenset({'"GET /reset.css HTTP/1.1"'}) -> frozenset({'"GET /style2.css HTTP/1.1"'})
# Support: 0.226
# Confidence: 0.9826086956521739
# Lift: 4.235382308845577
# =====================================
# Rule: frozenset({'"GET /favicon.ico HTTP/1.1"'}) -> frozenset({'"GET /images/jordan-80.png HTTP/1.1"', '"GET /images/web/2009/banner.png HTTP/1.1"'})
# Support: 0.18
# Confidence: 0.5806451612903225
# Lift: 2.6881720430107525
# =====================================
# Rule: frozenset({'"GET /favicon.ico HTTP/1.1"'}) -> frozenset({'"GET /images/jordan-80.png HTTP/1.1"', '"GET /reset.css HTTP/1.1"'})
# Support: 0.18
# Confidence: 0.5806451612903225
# Lift: 2.7132951462164603
# =====================================
# Rule: frozenset({'"GET /favicon.ico HTTP/1.1"'}) -> frozenset({'"GET /images/jordan-80.png HTTP/1.1"', '"GET /style2.css HTTP/1.1"'})
# Support: 0.18
# Confidence: 0.5806451612903225
# Lift: 2.7132951462164603
# =====================================
# Rule: frozenset({'"GET /favicon.ico HTTP/1.1"'}) -> frozenset({'"GET /reset.css HTTP/1.1"', '"GET /images/web/2009/banner.png HTTP/1.1"'})
# Support: 0.18
# Confidence: 0.5806451612903225
# Lift: 2.7388922702373706
# =====================================
# Rule: frozenset({'"GET /favicon.ico HTTP/1.1"'}) -> frozenset({'"GET /images/web/2009/banner.png HTTP/1.1"', '"GET /style2.css HTTP/1.1"'})
# Support: 0.18
# Confidence: 0.5806451612903225
# Lift: 2.7388922702373706
# =====================================
# Rule: frozenset({'"GET /favicon.ico HTTP/1.1"'}) -> frozenset({'"GET /reset.css HTTP/1.1"', '"GET /style2.css HTTP/1.1"'})
# Support: 0.18
# Confidence: 0.5806451612903225
# Lift: 2.5692263773908075
# =====================================
# Rule: frozenset({'"GET /images/jordan-80.png HTTP/1.1"'}) -> frozenset({'"GET /reset.css HTTP/1.1"', '"GET /images/web/2009/banner.png HTTP/1.1"'})
# Support: 0.212
# Confidence: 0.9464285714285714
# Lift: 4.464285714285714
# =====================================
# Rule: frozenset({'"GET /images/jordan-80.png HTTP/1.1"'}) -> frozenset({'"GET /images/web/2009/banner.png HTTP/1.1"', '"GET /style2.css HTTP/1.1"'})
# Support: 0.212
# Confidence: 0.9464285714285714
# Lift: 4.464285714285714
# =====================================
# Rule: frozenset({'"GET /images/jordan-80.png HTTP/1.1"'}) -> frozenset({'"GET /reset.css HTTP/1.1"', '"GET /style2.css HTTP/1.1"'})
# Support: 0.214
# Confidence: 0.9553571428571428
# Lift: 4.22724399494311
# =====================================
# Rule: frozenset({'"GET /images/web/2009/banner.png HTTP/1.1"'}) -> frozenset({'"GET /reset.css HTTP/1.1"', '"GET /style2.css HTTP/1.1"'})
# Support: 0.212
# Confidence: 0.9636363636363636
# Lift: 4.263877715205148
# =====================================
# Rule: frozenset({'"GET /favicon.ico HTTP/1.1"'}) -> frozenset({'"GET /images/jordan-80.png HTTP/1.1"', '"GET /images/web/2009/banner.png HTTP/1.1"', '"GET /reset.css HTTP/1.1"'})
# Support: 0.18
# Confidence: 0.5806451612903225
# Lift: 2.7388922702373706
# =====================================
# Rule: frozenset({'"GET /favicon.ico HTTP/1.1"'}) -> frozenset({'"GET /images/jordan-80.png HTTP/1.1"', '"GET /style2.css HTTP/1.1"', '"GET /images/web/2009/banner.png HTTP/1.1"'})
# Support: 0.18
# Confidence: 0.5806451612903225
# Lift: 2.7388922702373706
# =====================================
# Rule: frozenset({'"GET /favicon.ico HTTP/1.1"'}) -> frozenset({'"GET /images/jordan-80.png HTTP/1.1"', '"GET /style2.css HTTP/1.1"', '"GET /reset.css HTTP/1.1"'})
# Support: 0.18
# Confidence: 0.5806451612903225
# Lift: 2.7132951462164603
# =====================================
# Rule: frozenset({'"GET /favicon.ico HTTP/1.1"'}) -> frozenset({'"GET /reset.css HTTP/1.1"', '"GET /style2.css HTTP/1.1"', '"GET /images/web/2009/banner.png HTTP/1.1"'})
# Support: 0.18
# Confidence: 0.5806451612903225
# Lift: 2.7388922702373706
# =====================================
# Rule: frozenset({'"GET /images/jordan-80.png HTTP/1.1"'}) -> frozenset({'"GET /images/web/2009/banner.png HTTP/1.1"', '"GET /style2.css HTTP/1.1"', '"GET /reset.css HTTP/1.1"'})
# Support: 0.212
# Confidence: 0.9464285714285714
# Lift: 4.464285714285714
# =====================================
# Rule: frozenset({'"GET /favicon.ico HTTP/1.1"'}) -> frozenset({'"GET /images/jordan-80.png HTTP/1.1"', '"GET /reset.css HTTP/1.1"', '"GET /style2.css HTTP/1.1"', '"GET /images/web/2009/banner.png HTTP/1.1"'})
# Support: 0.18
# Confidence: 0.5806451612903225
# Lift: 2.7388922702373706
# =====================================
